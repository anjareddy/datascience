# %%
import numpy as np
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.set_xlim([-1, 2])
ax.set_ylim([-1, 2])
plt.axline((0, 0.25), (1, 0.25),  linewidth=1, color='g')
plt.axline((0, 0.75), (1, 0.75),  linewidth=1, color='g')
# plt.axline((0.25, 0), (0.25, 1), linewidth=1, color='g')
# plt.axline((0.75, 0), (0.75, 1), linewidth=1, color='g')
plt.grid()
plt.plot(0, 0, marker="o", markersize=10, markeredgecolor="red", markerfacecolor="red")
plt.plot(0.5, 0.5, marker="o", markersize=10, markeredgecolor="green", markerfacecolor="green")
plt.plot(0, 1, marker="o", markersize=10, markeredgecolor="red", markerfacecolor="red")
plt.plot(1, 0, marker="o", markersize=10, markeredgecolor="red", markerfacecolor="red")
plt.plot(1, 1, marker="o", markersize=10, markeredgecolor="red", markerfacecolor="red")
