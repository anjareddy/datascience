# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

df = pd.read_csv("iris-dataset.csv")
df.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width             type
# 0           5.1          3.5           1.4          0.2      Iris-setosa
# 1           4.9          3.0           1.4          0.2      Iris-setosa
# 2           5.7          3.2           1.3          0.2  Iris-versicolor
# 3           5.9          3.0           5.1          1.8   Iris-virginica

# %%
df.columns
# Out:
# Index(['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'type'], dtype='object')

# %%
d = df[['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'type']]
parallel_coordinates(d, 'type', color=["red", "green", "blue", "yellow"])
# Out:
# <Axes: >
